# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# Split text and labels
X = df['text']
y = df['label_num']

# Create TF-IDF vectorizer
tfidf = TfidfVectorizer(stop_words='english')

# Fit & transform the text data
X_tfidf = tfidf.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 from sklearn.model_selection import train_test_split
#       4 # Split text and labels
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sys
!"{sys.executable}" -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 10.4 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.7 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/8.7 MB 4.6 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.7 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.7 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 4.0 MB/s eta 0:00:01
# ...

# %%
import sys
!"{sys.executable}" -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sklearn
print("sklearn version:", sklearn.__version__)
# Out:
# sklearn version: 1.7.2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# Split text and labels
X = df['text']
y = df['label_num']

# Create TF-IDF vectorizer
tfidf = TfidfVectorizer(stop_words='english')

# Fit & transform the text data
X_tfidf = tfidf.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from sklearn.model_selection import train_test_split
#       4 # Split text and labels
# ----> 5 X = df['text']
#       6 y = df['label_num']
#       8 # Create TF-IDF vectorizer
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# load the CSV you created earlier
df = pd.read_csv("spam.csv")

# recreate the numeric label column
df['label_num'] = df.label.map({'ham': 0, 'spam': 1})

df.head()
# Out:
#   label                                               text  label_num
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

X = df['text']
y = df['label_num']

tfidf = TfidfVectorizer(stop_words='english')
X_tfidf = tfidf.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((4457, 8444), (1115, 8444))

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Create the Naive Bayes model
model = MultinomialNB()

# Train the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Confusion Matrix
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.979372197309417
#
# Confusion Matrix:
#  [[966   0]
#  [ 23 126]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       966
#            1       1.00      0.85      0.92       149
#
#     accuracy                           0.98      1115
#    macro avg       0.99      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
# Predict custom messages

def predict_message(msg):
    msg_tfidf = tfidf.transform([msg])
    pred = model.predict(msg_tfidf)[0]
    return "SPAM 🚫" if pred == 1 else "NOT SPAM ✅"

# Test a few messages
print(predict_message("Congratulations! You won a free iPhone!!"))
print(predict_message("Hey bro, are you coming to class today?"))
print(predict_message("Claim your free lottery now!!!"))
print(predict_message("Your bill has been successfully paid."))
# Out:
# SPAM 🚫
# NOT SPAM ✅
# SPAM 🚫
# NOT SPAM ✅

# %%
user_msg = input("Enter a message: ")
print("Prediction:", predict_message(user_msg))
# Out:
# Enter a message:  "Free money click here"  "Tomorrow assignment submission"  "You won cash reward"
# Prediction: NOT SPAM ✅

# %%
user_msg = input("Enter a message: ")
print("Prediction:", predict_message(user_msg))
# Out:
# Enter a message:  "Free money click here"
# Prediction: NOT SPAM ✅

# %%
predict_message("Congratulations you won a free gift!!!")
# Out:
# 'SPAM 🚫'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sanjay'
